# %%
# 政府採購爬蟲
# url: https://web.pcc.gov.tw/prkms/prms-searchBulletionClient.do?root=tps

# request method: Post
import pymongo

client = pymongo.MongoClient("mongodb+srv://mimas9107:Zaq12wsxcde3@cluster0.amkt2.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.govbuy
col = db['訓練']
A1='機關名稱'
B1='標案名稱'
C1='捷標日期'
D1='網址'
E1='聯絡人'
F1='聯絡電話'
G1='預算金額'

# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import random
header1={
    "User-Agent":"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}
header2={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36"
}
header3={
    "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.72 Safari/537.36"
}
headers_list=[header1,header2,header3]

headers=random.choice(headers_list)

# %%
url="https://web.pcc.gov.tw/prkms/prms-searchBulletionClient.do?root=tps"
form_data={
    "tmpQuerySentence": None,
    "timeRange": "110/1/1-110/12/31",
    "querySentence": "訓練",
    "tenderStatusType": "招標",
    "sortCol": "TENDER_NOTICE_DATE",
    "timeRangeTemp": "110/1/1-110/12/31",
    "sym": "on",
    "itemPerPage": "50"}

res=requests.post(url,form_data,headers=headers)
soup = BeautifulSoup(res.text)
time0 = time.time()
page=0
while page<65:
    page+=1
#    print('https://web.pcc.gov.tw/prkms/prms-searchBulletionClient.do'+soup.find_all('a',title='前往下一頁')[0]['href'])

    for case in soup.select('tbody')[0].select('tr'):
        
        time1=time.time()
        headers=random.choice(headers_list)
        res2=requests.get("https://web.pcc.gov.tw"+case.select('td')[3].a['href'],headers=headers)
        soup2 = BeautifulSoup(res2.text)
        time.sleep(random.randint(10,20))
#         print(soup2.select('table')[0].select('tr')[58].select('td')[0].text.replace('\t','').replace('\r','').replace('\n',''))
        
        i=40
        while i<61:
            i+=1
            if soup2.select('table')[0].select('tr')[i].select('th')[0].string == '聯絡人':
                print('聯絡人:',soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n',''))
                E2=soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n','')
            if soup2.select('table')[0].select('tr')[i].select('th')[0].string == '聯絡電話':
                print('聯絡電話:',soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n',''))
                F2=soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n','')
            if soup2.select('table')[0].select('tr')[i].select('th')[0].string == '預算金額':
                print('預算金額:',soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n',''))
                G2=soup2.select('table')[0].select('tr')[i].select('td')[0].text.replace('\t','').replace('\r','').replace('\n','')
        
        
        print('單位:',case.select('td')[2].string)
        A2=case.select('td')[2].string
        print('標案名稱:',case.select('td')[3].a.div.string)
        B2=case.select('td')[3].a.div.string
        print('截止日期:',case.select('td')[6].string)
        C2=case.select('td')[6].string
        # print("https://web.pcc.gov.tw"+case.select('td')[3].a['href'])
        D2="https://web.pcc.gov.tw"+case.select('td')[3].a['href']
        
        result=col.insert_one({A1:A2,B1:B2,C1:C2,D1:D2,E1:E2,F1:F2,G1:G2})
        print(result)
        time2=time.time()
        
        print('{:.2f}秒'.format(time2-time1))
        print('')
        
    print('****第{}頁爬取完成****'.format(page))
    
    # get and set the next page url
    url='https://web.pcc.gov.tw/prkms/prms-searchBulletionClient.do'+soup.find_all('a',title='前往下一頁')[0]['href']    
    
    headers=random.choice(headers_list)
    res=requests.post(url,form_data,headers=headers)
    soup = BeautifulSoup(res.text)
    time.sleep(random.randint(3,7))
    print(time2-time0)
# Out:
# 聯絡人: 卓春成
# 聯絡電話: (07)8711130分機33
# 預算金額: 249,900元
# 單位: 高雄市立鳳林國民中學
# 標案名稱: 空手道訓練場燈光改善工程
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf2c182980>
# 12.290236949920654sec
#
# 聯絡人: 規格需求:體育組何志崇  採購:朱麗安
# 聯絡電話: (03)3392400分機518
# 預算金額: 1,666,667元
# 單位: 桃園市立青溪國民中學
# 標案名稱: 110年度充實體育器材設備(資本門)
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fcf254de440>
# 15.52037239074707sec
#
# 聯絡人: 賓茂國小，承辦人：徐乙舜先生
# 聯絡電話: (089)771007分機13
# 預算金額: 300,000元
# 單位: 臺東縣政府
# 標案名稱: 賓茂國小--110年籃球訓練站體育館懸吊式籃架採購案
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf08ac2680>
# 15.256779193878174sec
#
# 聯絡人: 李汶洙
# 聯絡電話: (07)7410111分機8022
# 預算金額: 863,310元
# 單位: 台灣電力股份有限公司鳳山區營業處
# 標案名稱: 裝備及訓練器材乙批
# 截止日期: 110/07/13
# <pymongo.results.InsertOneResult object at 0x7fcf08ac4d40>
# 17.063910007476807sec
#
# 聯絡人: 鍾吉晟
# 聯絡電話: (02)27297668分機6517
# 預算金額: 200,000元
# 單位: 臺北市政府消防局
# 標案名稱: 110年度本局所屬各單位駐地大樓水塔及水池維護清潔案
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fcf088a2240>
# 14.074206590652466sec
#
# 聯絡人: 陳怡君
# 聯絡電話: (02)26095829分機134
# 預算金額: 3,803,613元
# 單位: 新北市立崇林國民中學
# 標案名稱: 崇林國中汙水下水道納管工程
# 截止日期: 110/07/13
# <pymongo.results.InsertOneResult object at 0x7fcf089b3d80>
# 13.18471074104309sec
#
# 聯絡人: 臺灣銀行採購部開標二科
# 聯絡電話: (02)23497673
# 預算金額: 20,920,000元
# 單位: 臺灣銀行股份有限公司
# 標案名稱: 香港分行洗錢防制系統名單掃描比對功能模組建置暨1年維護服務
# 截止日期: 110/07/23
# <pymongo.results.InsertOneResult object at 0x7fcf08d12c00>
# 13.120396614074707sec
#
# 聯絡人: 劉品伸
# 聯絡電話: (03)3255111分機3633
# 單位: 台灣中油股份有限公司煉製事業部桃園煉油廠
# 標案名稱: TESI點火控制系統配件(含安裝、測試及教育訓練等)
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf086fde00>
# 14.062022924423218sec
#
# 聯絡人: 王俊凱
# 聯絡電話: (8621)32569900分機123
# 預算金額: 7,914,456元
# 單位: 臺灣銀行股份有限公司
# 標案名稱: 大陸分行數據中心2021年度機房運維（含軟硬體維護）暨網路架構整改優化服務
# 截止日期: 110/07/23
# <pymongo.results.InsertOneResult object at 0x7fcf08dde600>
# 20.053314685821533sec
#
# 聯絡人: 洪宜楹
# 聯絡電話: (02)27110823
# 預算金額: 3,641,600元
# 單位: 中華民國舉重協會
# 標案名稱: 中華民國舉重協會110年度培育優秀或具潛力運動選手培育計畫訓練器材採購案(公告金額)
# 截止日期: 110/07/22
# <pymongo.results.InsertOneResult object at 0x7fcf08da3940>
# 16.073879957199097sec
#
# 聯絡人: 文小姐
# 聯絡電話: (06)3307990
# 預算金額: 199,500元
# 單位: 國防部陸軍司令部
# 標案名稱: 龍潭機場跑道助導航燈具電力設備採購
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf08de1500>
# 13.143065214157104sec
#
# 聯絡人: 陳育宏
# 聯絡電話: (06)5791311分機373
# 預算金額: 1,748,450元
# 單位: 臺灣菸酒股份有限公司隆田酒廠
# 標案名稱: 隆田酒廠高粱場區電氣開關箱增設中隔板等
# 截止日期: 110/07/22
# <pymongo.results.InsertOneResult object at 0x7fcf085d5fc0>
# 12.06290888786316sec
#
# 聯絡人: 曾雅婷
# 聯絡電話: (03)8462610分機123
# 預算金額: 1,421,920元
# 單位: 花蓮縣政府
# 標案名稱: 110年度改善運動訓練環境採購
# 截止日期: 110/07/20
# <pymongo.results.InsertOneResult object at 0x7fcf0896bcc0>
# 17.229191303253174sec
#
# 聯絡人: 歐聖凡
# 聯絡電話: (03)5712496分機8604
# 預算金額: 554,400元
# 單位: 新竹市東區東園國民小學
# 標案名稱: 110年度國小學生游泳能力教學
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf085da680>
# 21.1550714969635sec
#
# 聯絡人: 陳淑慧
# 聯絡電話: (02)26203646分機831
# 預算金額: 200,000元
# 單位: 新北市淡水區新興國民小學
# 標案名稱: 110年柔道角力隊訓練設施增設採購
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fcf0842c680>
# 14.076417922973633sec
#
# 聯絡人: 賴瑋新
# 聯絡電話: (07)6250919分機2036
# 預算金額: 6,920,000元
# 單位: 國防部軍醫局
# 標案名稱: 緊急發電機
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf0831f500>
# 16.187752723693848sec
#
# 聯絡人: 陳巧怡
# 聯絡電話: (05)5323927分機394
# 預算金額: 288,000元
# 單位: 台灣電力股份有限公司雲林區營業處
# 標案名稱: 110年度特約護理人員健康管理服務工作
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fcf0853f600>
# 18.17221713066101sec
#
# 聯絡人: 臺灣銀行採購部開標一科
# 聯絡電話: (02)23497661
# 預算金額: 13,268,000元
# 單位: 臺灣銀行股份有限公司
# 標案名稱: 資安治理評估暨資通安全事件應變輔導服務
# 截止日期: 110/07/30
# <pymongo.results.InsertOneResult object at 0x7fcf0818bac0>
# 21.131597995758057sec
#
# 聯絡人: 莊佳穎
# 聯絡電話: (02)87258207
# 單位: 台灣中油股份有限公司
# 標案名稱: 台中廠10吋超音波流量計兩套(含安裝測試及教育訓練)
# 截止日期: 110/07/26
# <pymongo.results.InsertOneResult object at 0x7fcf0807b780>
# 21.288826942443848sec
#
# 聯絡人: 楊月英
# 聯絡電話: (049)2982055分機136
# 預算金額: 1,458,265元
# 單位: 南投縣立埔里國民中學
# 標案名稱: 教育部體育署補助110年度體育班績優學校暨基層運動選手訓練站改善訓練環境及器材設備採購
# 截止日期: 110/07/21
# <pymongo.results.InsertOneResult object at 0x7fcf08210dc0>
# 19.161015510559082sec
#
# 聯絡人: 蔡鎔蔚
# 聯絡電話: (8621)32569900分機122
# 預算金額: 18,952,824元
# 單位: 臺灣銀行股份有限公司
# 標案名稱: 大陸分行數據中心軟硬體維護暨系統管理網路整合服務
# 截止日期: 110/07/30
# <pymongo.results.InsertOneResult object at 0x7fceefe47840>
# 11.143805265426636sec
#
# 聯絡人: 採購廖先生1094；規格綦先生1132
# 聯絡電話: (07)5821100
# 預算金額: 1,289,505元
# 單位: 國家運動訓練中心
# 標案名稱: 110年度器材室購置重型層架1批案
# 截止日期: 110/07/19
# <pymongo.results.InsertOneResult object at 0x7fcf0807ba40>
# 20.090771913528442sec
#
# 聯絡人: 社會處社會工作科 陳亞琦
# 聯絡電話: (08)7320415分機5398
# 預算金額: 230,000元
# 單位: 屏東縣政府
# 標案名稱: 110年屏東縣社會工作教育訓練
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefb8b040>
# 18.153505086898804sec
#
# 聯絡人: 林明緯
# 聯絡電話: (03)3321224分機605
# 預算金額: 2,150,000元
# 單位: 國軍退除役官兵輔導委員會退除役官兵職業訓練中心
# 標案名稱: 110年水電能源工程班「智慧居家控制系統」採購案
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefb8d240>
# 18.13570785522461sec
#
# 聯絡人: 鍾佩蓁
# 聯絡電話: (05)6962004分機814
# 預算金額: 198,362元
# 單位: 雲林縣崙背鄉崙背國民小學
# 標案名稱: 教育部體育署110年度補助基層運動選手訓練站改善訓練環境及器材設備計畫
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefb8b140>
# 12.344331979751587sec
#
# 聯絡人: 王祥融
# 聯絡電話: (02)25024366分機152
# 預算金額: 645,800元
# 單位: 臺北市中山區長春國民小學
# 標案名稱: 110年度補助基層運動選手訓練站改善訓練環境及器材設備採購案
# 截止日期: 110/07/19
# <pymongo.results.InsertOneResult object at 0x7fceeff42400>
# 13.193038940429688sec
#
# 聯絡人: 羅金池
# 聯絡電話: (03)3286045分機1231
# 預算金額: 802,620元
# 單位: 台灣電力股份有限公司訓練所
# 標案名稱: 第63期養成班學員工作服273套
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fceefafbf40>
# 11.159299850463867sec
#
# 聯絡人: 林務科李伶萱
# 聯絡電話: (037)558219
# 預算金額: 2,020,215元
# 單位: 苗栗縣政府
# 標案名稱: 110年度苗栗縣泰安鄉、南庄鄉沿線道路綠美化養護工程(第二次採購)
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefa69780>
# 18.11315608024597sec
#
# 聯絡人: 採購官
# 聯絡電話: (038)266150
# 預算金額: 255,000元
# 單位: 國防部空軍司令部
# 標案名稱: 營區扁柏移植案
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefbcfd00>
# 17.224087953567505sec
#
# 聯絡人: 採購官
# 聯絡電話: (038)266150
# 預算金額: 861,000元
# 單位: 國防部空軍司令部
# 標案名稱: 電動掃地機構置案
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fceefbd0f40>
# 15.106119394302368sec
#
# 聯絡人: 孫誠志
# 聯絡電話: (05)2766602分機303
# 預算金額: 400,000元
# 單位: 嘉義市立北興國民中學
# 標案名稱: 嘉義市立北興國民中學110年度基層運動選手訓練站改善訓練環境及器材設備採購
# 截止日期: 110/07/13
# <pymongo.results.InsertOneResult object at 0x7fcf088bf400>
# 20.091075897216797sec
#
# 聯絡人: 龔士官長
# 聯絡電話: (03)4607306
# 預算金額: 192,970元
# 單位: 國防部陸軍司令部
# 標案名稱: 湖口四營區變電站電流保護電驛等17項
# 截止日期: 110/07/13
# <pymongo.results.InsertOneResult object at 0x7fceefcdc600>
# 17.10045862197876sec
#
# 聯絡人: 採購官
# 聯絡電話: (038)266150
# 預算金額: 1,744,226元
# 單位: 國防部空軍司令部
# 標案名稱: 修護棚廠整修工程
# 截止日期: 110/07/12
# <pymongo.results.InsertOneResult object at 0x7fcf0895c500>
# 13.159517288208008sec
#
# 聯絡人: 需求單位劉先生分機1401(規格).劉先生(作業)
# 聯絡電話: (03)9365027分機2001
# 預算金額: 589,000元
# 單位: 宜蘭縣政府消防局
# 標案名稱: 「110年度海洋委員會補助購置海域救生器材裝備1批採購案」
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf0895c440>
# 13.100786924362183sec
#
# 聯絡人: 黃先生
# 聯絡電話: (04)25814625分機532223
# 預算金額: 633,000元
# 單位: 國防部陸軍司令部
# 標案名稱: 110年度番仔寮火砲實彈射擊訓練場影響地方睦鄰捐助環境監測勞務採購
# 截止日期: 110/07/12
# <pymongo.results.InsertOneResult object at 0x7fcf08a33e40>
# 16.151235103607178sec
#
# 聯絡人: 吳先生(需求)/林小姐(採購)
# 聯絡電話: (03)4855368分機1619/1115
# 預算金額: 6,298,000元
# 單位: 勞動部勞動力發展署桃竹苗分署
# 標案名稱: 「110年訓練四、五館及綜合大樓變頻式空調設備建置」採購案
# 截止日期: 110/08/09
# <pymongo.results.InsertOneResult object at 0x7fcf08a33040>
# 18.22807788848877sec
#
# 聯絡人: 陳怡玟
# 聯絡電話: (03)3525580分機511
# 預算金額: 1,440,480元
# 單位: 桃園市立南崁高級中等學校
# 標案名稱: 110年度基層運動選手訓練站射擊設備器材
# 截止日期: 110/07/20
# <pymongo.results.InsertOneResult object at 0x7fcf080cff00>
# 14.136121034622192sec
#
# 聯絡人: 林智育
# 聯絡電話: (049)2222110分機110
# 預算金額: 272,000元
# 單位: 南投縣南投市公所
# 標案名稱: 南投市立幼兒園110學年度-音樂課程聘請專任教師
# 截止日期: 110/07/14
# <pymongo.results.InsertOneResult object at 0x7fcf08b29fc0>
# 16.06620168685913sec
#
# 聯絡人: 李伶萱
# 聯絡電話: (037)558219
# 預算金額: 3,791,492元
# 單位: 苗栗縣政府
# 標案名稱: 110年度苗栗縣縣道124線、124甲線、124乙線暨周邊沿線綠美化養護工程
# 截止日期: 110/07/13
# <pymongo.results.InsertOneResult object at 0x7fcf08660ac0>
# 18.16389012336731sec
#
# 聯絡人: 黃先生
# 聯絡電話: (04)25814625分機532223
# 預算金額: 1,980,000元
# 單位: 國防部陸軍司令部
# 標案名稱: 興中山莊健身房重量訓練器材採購案
# 截止日期: 110/07/12
# <pymongo.results.InsertOneResult object at 0x7fcf082d3ec0>
# 14.208713293075562sec
#
# 聯絡人: 林智育
# 聯絡電話: (049)2222110分機110
# 預算金額: 192,000元
# 單位: 南投縣南投市公所
# 標案名稱: 南投市立幼兒園110學年度-體能課程聘請專任教師
# 截止日期: 110/07/15
# <pymongo.results.InsertOneResult object at 0x7fcf082d18c0>
# 21.081968784332275sec
#
# 聯絡人: 謝明修
# 聯絡電話: (02)29111680
# 預算金額: 4,800,000元
# 單位: 國防部
# 標案名稱: 110年委外網路專精訓練案
# 截止日期: 110/07/19
# <pymongo.results.InsertOneResult object at 0x7fcf08a373c0>
# 20.408246517181396sec
#
# 聯絡人: 彭姿燁/呂玉方
# 聯絡電話: (02)89956399分機3532/1606
# 預算金額: 905,100元
# 單位: 勞動部勞動力發展署北基宜花金馬分署
# 標案名稱: 基隆職業訓練場-後棟地下室電路盤改善
# 截止日期: 110/07/22
# <pymongo.results.InsertOneResult object at 0x7fcf08b549c0>
# 17.357780694961548sec
# 聯絡人: 黃紹豪
# 聯絡電話: (04)23335627分機408
# 預算金額: 8,872,500元
# 單位: 台灣電力股份有限公司台中供電區營運處
# 標案名稱: 備援系統主機及網路設備等一批
# 截止日期: 110/07/19
# <pymongo.results.InsertOneResult object at 0x7fcf08864780>
# 18.080531120300293sec
#
# 聯絡人: 黃全興
# 聯絡電話: (07)6912811分機3351
# 預算金額: 16,800,000元
# 單位: 台灣電力股份有限公司興達發電廠
# 標案名稱: 複3機氣渦輪機組Repowering保溫及排氣煙道升級改善工作
# 截止日期: 110/07/28
# <pymongo.results.InsertOneResult object at 0x7fcf08a3aec0>
# 14.129507303237915sec
