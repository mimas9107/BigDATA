# %%
import numpy as np
import requests

# %%
# url="https://www.cwb.gov.tw/V8/C/W/OBS_County.html?ID=63"
url="https://www.cwb.gov.tw/Data/js/Observe/County/63.js?_=1619241828978"
headers={
    "Host": "www.cwb.gov.tw",
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:87.0) Gecko/20100101 Firefox/87.0",
    "Connection": "keep-alive",
    "Cookie": "_ga_K6HENP0XVS=GS1.1.1619241678.5.1.1619242111.0; _ga=GA1.3.588699186.1617553853; TabIndex_Sat=Tab2; AreaIndex_Sat=Area1; TS010c55bd=0107dddfefa5ecaed8d7696dc4367749e77ca3f090f5fc2c3cfd9e60ae9e203bf8c731d7a60fbea07a682b7250850ec5962236b9cf; TS558d33eb027=08dc4bbcbbab2000ce0a94167140c0e5c027177839e82978451dea009e27370de6a12ea535880a5808e17b4199113000d8d2cc82b25045f317ce6802a243565b976ba23b514b8af21e650159a4704f55c945346deba5127485657707b54311b6; _gid=GA1.3.1096461088.1619241679"
}

# %%
result = requests.get(url,headers=headers)
print(result)
# Out:
# <Response [200]>

# %%
print(result.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="zh-Hant-TW" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="zh-Hant-TW" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="zh-Hant-TW">
# <!--<![endif]-->
#
# <head>
#   <title>縣市測站列表 | 交通部中央氣象局</title>
#    <!-- Meta -->
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta name="description" content="">
#   <meta name="author" content="">
#   <!--Facebook_meta_begin-->
#   <!-- Facebook -->
#   <meta property="og:url" content="https://www.cwb.gov.tw/V8/C/W/OBS_County.html" />
#   <meta property="og:image" content="https://www.cwb.gov.tw/Data/satellite/TWI_IR1_CR_800/TWI_IR1_CR_800.jpg" />
#   <meta property="og:title" content="全台測站分區 - 中央氣象局全球資訊網" />
#   <meta property="og:description" content="全台測站觀測分區列表" />
#   <meta property="og:site_name" content="中央氣象局全球資訊網" />
#   <!--Facebook_meta_end-->
#   <!--tw.gov_meta_begin-->
#   <meta name="DC.Creator" content="交通部中央氣象局" />
#   <meta name="DC.Contributor" content="交通部中央氣象局" />
#   <meta name="DC.Type" content="服務" />
#   <meta name="DC.Format" content="text" />
#   <meta name="DC.Source" content="交通部中央氣象局" />
#   <meta name="DC.Language" content="中文" />
#   <meta name="DC.coverage.t.min" content="2021-03-02" />
#   <meta name="DC.coverage.t.max" content="2026-03-02" />
#   <meta name="DC.Publisher" content="交通部中央氣象局" />
#   <meta name="DC.Date" content="2021-03-02 10:44" />
#   <meta name="DC.Identifier" content="315070000H" />
#   <meta name="DC.Relation" content="" />
#   <meta name="DC.Rights" content="交通部中央氣象局" />
#   <meta name="Category.Theme" content="650" />
#   <meta name="Category.Cake" content="CM0" />
#   <meta name="Category.Service" content="EZ0" />
#   <meta name="DC.Title" content="中央氣象局全球資訊網" />
#   <meta name="DC.Subject" content="天氣" />
#   <meta name="DC.Description" content="目前天氣" />
#   <meta name="Keywords" content="天氣,風向,風力,陣風,濕度,氣壓,雨量,能見度,日照" />
#   <!--tw.gov_meta_end-->
#   <!-- Favicon -->
#   <link rel="shortcut icon" href="/V8/favicon.ico">
#   <!-- =============== CSS Global Compulsory =============== -->
#   <!--common_css_begin-->
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="application-name" content="中央氣象局">
#   <meta name="msapplication-TileImage" content="/V8/assets/img/win10/cwbPinlogo.png">
#   <meta name="msapplication-square70x70logo" content="/V8/assets/img/win10/cwbPinlogo70.png">
#   <meta name="msapplication-square150x150logo" content="/V8/assets/img/win10/cwbPinlogo150.png">
#   <meta name="msapplication-square310x310logo" content="/V8/assets/img/win10/cwbPinlogo310.png">
#   <link rel="shortcut icon" href="/favicon.ico">
#   <link rel="stylesheet" href="/V8/assets/plugins/bootstrap/css/bootstrap.min.css?v=20191223">
#   <link rel="stylesheet" href="/V8/assets/plugins/font-awesome/css/font-awesome.min.css?v=20191223">
#   <link rel="stylesheet" href="/V8/assets/plugins/cwb-fonticon/style.css?v=20201208-3">
#   <link rel="stylesheet" href="/V8/assets/plugins/plugins.css?v=20191223">
#   <link rel="stylesheet" href="/V8/assets/css/main.css?v=20201224">
#   <!--common_css_end-->
#   <!-- =============== CSS Customization =============== -->
# </head>
#
# <body>
#   <a class="focusable" href="#center-content" title="跳到主要內容區塊" tabindex="1">跳到主要內容區塊</a>
#   <noscript>
#     <h2>您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態。</h2>
#     <a href="/V8/C/sitemap.html" target="_self" title="可點此前往" style="font-size:1.2rem;">網站導覽</a>
#   </noscript>
#   <!--=== Header ===-->
#   <header class="header" id="header"></header>
#   <!--=== End Header ===-->
#   <!--=== Breadcrumbs ===-->
#   <div class="breadcrumbs">
#     <div class="container">
# 	  <a href="#center-content" accesskey="C" id="center-content" class="acc" title=":::中間內容區導盲磚">:::</a>
#       <ul class="pull-right breadcrumb breadcrumb-left">
# 	    <li><a href="/V8/C/index.html" aria-label="首頁" target="_self"><i class="fa fa-home" aria-hidden="true" title="首頁"></i></a></li>
#         <li>天氣</li>
#         <li><a href="OBS_Map.html" title="顯示目前天氣頁面">目前天氣</a></li>
#         <li>縣市測站列表</li>
#       </ul>
#     </div>
#   </div>
#   <!--=== End Breadcrumbs ===-->
#   <div class="main-title-bar">
#     <div class="container default-flex">
#       <h2 class="main-title"><i class="icon-cwb-cloud" aria-hidden="true"></i>縣市測站列表 - </h2>
#     </div>
#    </div>
#   <!--=== Content Part ===-->
#   <form class="sky-form">
#     <fieldset>
#       <div class="container">
#         <div class="row">
#           <div class="col-md-1 col-sm-2 col-md-offset-4 col-sm-offset-2">
#             <label for="County" class="label text-right">請選擇</label>
#           </div>
#           <div class="col-md-2 col-sm-4">
# 		     <label class="select">
#                  <select id="County"></select>
#                   <i aria-hidden="true"></i>
#              </label>
#           </div>
#         </div>
#       </div>
#     </fieldset>
#   </form>
#   <div class="wrapper">
#     <main class="main-content container">
#       <div class="col-md-12">
#         <div class="row">
#           <!-- table-responsive -->
# 		  <div style="width:165px; top: -37px; left: calc(50% - 80px); border: 1px solid #1a67b1; border-radius: 10px; padding: 5px 8px; color: #1a67b1; margin-bottom:5px; position:absolute; "><i class="icon-warn" aria-hidden="true"></i> 點擊測站看詳細資料 </div>
#           <div class="flex_table mobile_table-month" id="StationData">
#             <div class="btn-group">
#               <a role="button" aria-label="上一頁" id="back"><i class="fa  fa-long-arrow-left"></i></a>
#               <a role="button" aria-label="下一頁" id="next"><i class="fa  fa-long-arrow-right"></i></a>
#             </div>
#             <table class="table table-striped version_5 href-tr table-bordered v2" id="sortTable">
#               <thead>
#                 <tr>
#                   <th scope="col" id="station" class="height-100">測站名稱</th>
# 				  <th scope="col" id="OBS_Time">觀測時間</th>
#                   <th scope="col" id="tem" class="headerSortUp">溫度</th>
#                   <th scope="col" id="weather" class="md-min-65 sm-min-80">天氣<br></th>
#                   <th scope="col" id="w-1">風向<br></th>
#                   <th scope="col" id="w-2">風力 級<br class="hidden-xs hidden-sm">m/s </th>
#                   <th scope="col" id="w-3">陣風 級<br class="hidden-xs hidden-sm">m/s</th>
# 				  <th scope="col" id="visible">能見度<br class="hidden-xs hidden-sm">(公里)</th>
#                   <th scope="col" id="hum">相對濕度<br class="hidden-xs hidden-sm">(%)</th>
#                   <th scope="col" id="pre">海平面氣壓(百帕)</th>
#                   <th scope="col" id="rain">當日累積<br>雨量(毫米</th>
#                   <th scope="col" id="sunlight">日照時數<br></th>
#                 </tr>
#               </thead>
#               <tbody id="stations">
#               </tbody>
#             </table>
#           </div>
#         </div>
# 		    <div class="row">
#                 <div class="other">
#                  <p class="note-md">註</p>
#                   <ul class="list-unstyled">
#                   <li>本表中「<b>-</b>」代表無（觀測）資料。</li>
#                   </ul>
#                 </div>
#              </div>
#       </div>
#     </main>
#   </div>
#   <!--/wrapper-->
#   <!--/container-->
#   <!-- End Content Part -->
#   <!--=== Footer ===-->
#   <footer id="footer-v3" class="footer-v3"></footer>
#   <!--=== End Footer ===-->
#   <!-- JS Weather Data -->
#   <script src="/Data/js/info/Info_County.js?"></script>
#   <script src="/Data/js/info/Info_AreaCounty.js?"></script>
#   <!--common_js_begin-->
#   <script src="/Data/js/warn/Warning_Content.js?"></script>
#   <script src="/Data/js/info/Info_Warning.js?v=20200824"></script>
#   <script src="/Data/js/info/Info_County.js?v=20200415"></script>
#   <script src="/Data/js/info/Info_Town.js?v=20200817"></script>
#   <script src="/V8/assets/plugins/jquery/jquery-2.2.4.min.js"></script>
#   <script src="/V8/assets/plugins/jquery/jquery-migrate.min.js"></script>
#   <script src="/V8/assets/plugins/jquery-ui/jquery-ui.min.js"></script>
#   <script src="/V8/assets/plugins/bootstrap/js/bootstrap.min.js"></script>
#   <script src="/V8/assets/plugins/back-to-top.js"></script>
#   <script src="/V8/assets/plugins/smoothScroll.js"></script>
#   <script src="/V8/assets/js/cookie_lib.js?v=20201217"></script>
#   <script src="/V8/assets/js/function-global.js?v=20210302"></script>
#   <script src="/V8/assets/js/app.js"></script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async src="https://www.googletagmanager.com/gtag/js?id=UA-126485471-1"></script>
#   <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-126485471-1');
#   </script>
#   <!--common_js_end-->
#   <script src="/V8/assets/js/function-table.js"></script>
#   <script src="/V8/assets/js/observe/function-sort-obs.js"></script>
#   <script src="/V8/assets/js/NewsHot.js?"></script>
#   <script type="text/javascript">
#      // 手機版表格切換欄位數
# 		var VER = "C";
#         var interval = [3, 3, 3, 2];
#         var URL = window.location.href;
#         var regex = new RegExp("[?&]ID(=([^&#]*)|&|#|$)"), Results = regex.exec(URL);
#
# 		if (Results) {
# 		   TID = encodeURIComponent(Results[2]);
# 		   if ( TID != "0")
# 		    CID = TID.substring(0, TID.length);
#         }
# 	 	//我的最愛First，預設台北市
# 		var FavoriteID = getCookie('V8_FAVORITE');
# 		//不同瀏覽器FavoriteID會不同
#         if (FavoriteID == null)  FavoriteID = "";
# 		console.log('FavoriteID:'+ FavoriteID);
# 		if ( CID == "menu" ) {
# 		   if ( FavoriteID != "" ) {
# 		     //判斷我的最愛是否超過1個
# 		     if(FavoriteID.substr(0,FavoriteID.indexOf("-"))) {
# 		       CID = FavoriteID.substr(0,FavoriteID.indexOf("-"));
# 			   console.log('FavoriteID:'+ CID);
# 		     } else {
#                CID = FavoriteID;
# 			   console.log('FavoriteID:'+ CID);
# 			 }
#            } else {
#               CID = 63;
# 			  console.log('DefaultID:63');
#            }
# 		}
#
# 	 //MainTitle
# 		$.each(Info_County, function(i){
# 		if( Info_County[i].ID == CID ){
# 			$('.main-title').append(Info_County[i].Name[VER]);
# 		  }
# 	    });
#         console.log('CID:'+CID);
#
#    //=============  公告訊息    ===============
#    var MOD_FILE2="/Data/js/Data_News.js?";
#    $.get(MOD_FILE2, '', function(data) {
#      NewsHot(Obser_News[VER]);
#      console.log( 'Get '+MOD_FILE2+' Success' );
#     }).fail(function(){
#      console.log( 'Get '+MOD_FILE2+' Failed!' );
#    });
#    //============= 公告訊息 END ===============
#
# 	 jQuery(document).ready(function() {
#         App.init();
#      });
#   </script>
#   <script src="/V8/assets/js/observe/OBS_County.js?v=20201016"></script>
#   <!--[if lt IE 9]>
#     <script src="/V8/assets/plugins/IE/respond.js"></script>
#     <script src="/V8/assets/plugins/IE/html5shiv.js"></script>
#     <script src="/V8/assets/plugins/IE/placeholder-IE-fixes.js"></script>
#     <![endif]-->
# </body>
#
# </html>
